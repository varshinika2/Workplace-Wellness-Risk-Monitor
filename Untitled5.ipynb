# %% [markdown]
# <a href="https://colab.research.google.com/github/varshinika2/Workplace-Wellness-Risk-Monitor/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas numpy seaborn scikit-learn matplotlib --quiet

# %%
import pandas as pd
import numpy as np

# Load the dataset
df = pd.read_csv('/content/healthcare_dataset.csv')

# Drop unnecessary columns for health monitoring
columns_to_use = ['Age', 'Medical Condition', 'Billing Amount', 'Admission Type', 'Medication', 'Test Results']
df = df[columns_to_use].copy()

# Encode categorical features
df['Medical Condition'] = df['Medical Condition'].astype('category').cat.codes
df['Admission Type'] = df['Admission Type'].astype('category').cat.codes
df['Medication'] = df['Medication'].astype('category').cat.codes
df['Test Results'] = df['Test Results'].map({'Normal': 0, 'Abnormal': 1, 'Inconclusive': 0.5})

# Drop missing values if any
df = df.dropna()

print("✅ Data preprocessed successfully")
df.head()
# Out:
# ✅ Data preprocessed successfully
#    Age  Medical Condition  Billing Amount  Admission Type  Medication  \
# 0   30                  2    18856.281306               2           3
# 1   62                  5    33643.327287               1           1
# 2   76                  5    27955.096079               1           0
# 3   28                  3    37909.782410               0           1
# 4   43                  2    14238.317814               2           4
#
#    Test Results
# 0           0.0
# 1           0.5
# 2           0.0
# 3           1.0
# 4           1.0

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
features = ['Age', 'Medical Condition', 'Billing Amount', 'Admission Type', 'Medication', 'Test Results']
df_scaled = scaler.fit_transform(df[features])

# %%
from sklearn.ensemble import IsolationForest

iso = IsolationForest(contamination=0.05, random_state=42)
df['Anomaly'] = iso.fit_predict(df_scaled)
df['Risk Score'] = -iso.decision_function(df_scaled)

print("✅ Anomaly detection complete")
# Out:
# ✅ Anomaly detection complete

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=42)
df['Risk Group'] = kmeans.fit_predict(df[['Risk Score']])

# Label risk groups
df['Risk Label'] = df['Risk Group'].map({0: 'Low Risk', 1: 'Medium Risk', 2: 'High Risk'})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Risk Score', hue='Risk Label', kde=True, palette='coolwarm')
plt.title('Distribution of Risk Scores by Group')
plt.xlabel('Risk Score')
plt.grid(True)
plt.show()

# %%
report_name = "workplace_wellness_monitor_output.csv" #make sure you run the command to get the report
df.to_csv(report_name, index=False)

from google.colab import files
files.download(report_name)

# %%
df['BRI'] = (
    (df['Medical Condition'] * 0.4) +
    (df['Medication'] * 0.2) +
    (df['Test Results'] * 0.4)
) * 25  # Scale to 100

# %%
df['Medical Intensity'] = (
    (df['Billing Amount'].rank(pct=True)) * 0.5 +
    (df['Admission Type'] / df['Admission Type'].max()) * 0.3 +
    (df['Test Results']) * 0.2
) * 100

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Billing Amount', y='Risk Score', hue='Risk Label', palette='coolwarm', alpha=0.7)
plt.title('Risk Score vs Billing Amount')
plt.xlabel('Billing Amount')
plt.ylabel('Risk Score')
plt.grid(True)
plt.show()

# %%
condition_risk = df.groupby('Medical Condition')['Risk Score'].mean().sort_values()
plt.figure(figsize=(10, 6))
condition_risk.plot(kind='barh', color='darkcyan')
plt.title('Average Risk Score by Medical Condition')
plt.xlabel('Risk Score')
plt.grid(axis='x')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='Risk Label', y='Age', palette='Set3')
plt.title('Age Distribution by Risk Group')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-28-133497331.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Risk Label', y='Age', palette='Set3')

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='Risk Score', bins=30, hue='Risk Label', kde=True, palette='viridis')
plt.title('Risk Score Distribution')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.stripplot(data=df, x='Stay Duration', y='Risk Score', hue='Risk Label', jitter=True, palette='Set1')
plt.title('Stay Duration vs Risk Score')
plt.grid(True)
plt.show()

# %%
# !pip install ipywidgets --quiet

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from ipywidgets import interact, widgets, VBox, HBox

# For better plots in Colab
# %matplotlib inline

# Load your cleaned dataset (already processed)
df = pd.read_csv('/content/healthcare_dataset.csv')  # Adjust if needed

# Display some basic info
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
# Set ranges for Age and Billing
age_slider = widgets.IntRangeSlider(
    value=[20, 60],
    min=int(df['Age'].min()),
    max=int(df['Age'].max()),
    step=1,
    description='Age Range:',
    continuous_update=False
)

billing_slider = widgets.FloatRangeSlider(
    value=[df['Billing Amount'].min(), df['Billing Amount'].max()],
    min=float(df['Billing Amount'].min()),
    max=float(df['Billing Amount'].max()),
    step=10.0,
    description='Billing Amt:',
    continuous_update=False
)

risk_dropdown = widgets.Dropdown(
    options=['All', 'Low Risk', 'Medium Risk', 'High Risk'],
    value='All',
    description='Risk Level:'
)

# %%
def show_filtered_data(age_range, billing_range, risk_level):
    # Filter dataset
    filtered_df = df[
        (df['Age'] >= age_range[0]) & (df['Age'] <= age_range[1]) &
        (df['Billing Amount'] >= billing_range[0]) & (df['Billing Amount'] <= billing_range[1])
    ]

    if risk_level != 'All':
        filtered_df = filtered_df[filtered_df['Risk Label'] == risk_level]

    # Display summary
    print(f"👥 Employees in selection: {len(filtered_df)}")
    display(filtered_df[['Age', 'Billing Amount', 'Medical Condition', 'Risk Score', 'Risk Label', 'Intervention']].head())

    # Plot Risk Score distribution
    plt.figure(figsize=(10, 5))
    sns.histplot(filtered_df['Risk Score'], kde=True, color='steelblue')
    plt.title('Filtered Risk Score Distribution')
    plt.xlabel('Risk Score')
    plt.grid(True)
    plt.show()

# %%
# Encode text fields into numeric categories
df['Medical Condition'] = df['Medical Condition'].astype('category').cat.codes
df['Admission Type'] = df['Admission Type'].astype('category').cat.codes
df['Medication'] = df['Medication'].astype('category').cat.codes

# Map test results (if not numeric yet)
if df['Test Results'].dtype == 'object':
    df['Test Results'] = df['Test Results'].map({
        'Normal': 0, 'Abnormal': 1, 'Inconclusive': 0.5
    })

# %%
from sklearn.preprocessing import StandardScaler

features = ['Age', 'Medical Condition', 'Billing Amount', 'Admission Type', 'Medication', 'Test Results']
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df[features])

# %%
print(df[features].dtypes)
# Out:
# Age                    int64
# Medical Condition       int8
# Billing Amount       float64
# Admission Type          int8
# Medication              int8
# Test Results         float64
# dtype: object

# %%
# Re-import if needed
from sklearn.ensemble import IsolationForest
from sklearn.cluster import KMeans

# Recalculate if not done
features = ['Age', 'Medical Condition', 'Billing Amount', 'Admission Type', 'Medication', 'Test Results']
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df[features])

# Anomaly Detection
iso = IsolationForest(contamination=0.05, random_state=42)
df['Risk Score'] = -iso.fit(df_scaled).decision_function(df_scaled)

# Clustering
kmeans = KMeans(n_clusters=3, random_state=42)
df['Risk Group'] = kmeans.fit_predict(df[['Risk Score']])

# %%
# Map cluster numbers to readable labels (adjust if needed)
cluster_map = {
    df.groupby('Risk Group')['Risk Score'].mean().idxmin(): 'Low Risk',
    df.groupby('Risk Group')['Risk Score'].mean().median(): 'Medium Risk',
    df.groupby('Risk Group')['Risk Score'].mean().idxmax(): 'High Risk'
}

df['Risk Label'] = df['Risk Group'].map(cluster_map)

# %%
print(df[['Risk Score', 'Risk Group', 'Risk Label']].head())
# Out:
#    Risk Score  Risk Group Risk Label
# 0   -0.073164           1   Low Risk
# 1   -0.076775           1   Low Risk
# 2   -0.032428           0        NaN
# 3   -0.042587           0        NaN
# 4   -0.042923           0        NaN

# %%
import numpy as np

# Precompute threshold to avoid recalculating
high_risk_score_threshold = df['Risk Score'].quantile(0.95)

# Define conditions
conditions = [
    df['Risk Score'] > high_risk_score_threshold,
    df['Risk Label'] == 'High Risk',
    df['Risk Label'] == 'Medium Risk'
]

# Define corresponding outputs
choices = [
    'Immediate Diagnostic Follow-up',
    'Weekly Health Counseling',
    'Monthly Monitoring'
]

# Default intervention if none of the above matched
default = 'Quarterly Wellness Tips'

# Apply the conditions
df['Intervention'] = np.select(conditions, choices, default=default)

# %%
#interactive dashboard
interact(show_filtered_data, age_range=age_slider, billing_range=billing_slider, risk_level=risk_dropdown);
# Out:
# interactive(children=(IntRangeSlider(value=(20, 60), continuous_update=False, description='Age Range:', max=89…

# %%
from IPython.display import FileLink

def export_filtered(age_range, billing_range, risk_level):
    filtered_df = df[
        (df['Age'] >= age_range[0]) & (df['Age'] <= age_range[1]) &
        (df['Billing Amount'] >= billing_range[0]) & (df['Billing Amount'] <= billing_range[1])
    ]

    if risk_level != 'All':
        filtered_df = filtered_df[filtered_df['Risk Label'] == risk_level]

    filename = "filtered_intervention_report.csv"
    filtered_df.to_csv(filename, index=False)
    print(f"✅ Report saved as {filename}")
    return FileLink(filename)

interact(export_filtered, age_range=age_slider, billing_range=billing_slider, risk_level=risk_dropdown);
# Out:
# interactive(children=(IntRangeSlider(value=(20, 67), continuous_update=False, description='Age Range:', max=89…
